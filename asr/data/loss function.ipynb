# %%
path = "/home/hemant/asr_wm/data/save/without_space/with_lm/"
d_t = 'test'

import numpy as np
from tqdm import tqdm
import glob, os

start = [ "|", "$", "{"]
stop = [']']

def rea(file):
    with open(file, 'r') as f:
        dummy = f.read()
    l = ''
    w = ''
    for i in dummy:
        if i in start:
            l+= i
            w= '-'
        elif w == '-' and len(l) != 0:
            l+= i
        if i in stop:
            l+= ','
            w = ''
    return l[:-1].split(',')

true_ = glob.glob('/home/hemant/asr_wm/data/ner/txt/'+d_t+'/*.txt')
pred_ = glob.glob(path + d_t+ '/*.txt')

true = [rea(i) for i in true_]
pred = [rea(i) for i in pred_]

t = []
for i in true:
    for j in i:
        t.append(j)
        
t_ = []
for i in t:
    s,st =0, 0
    for j in i:
        if j in start:
            s+=1
        if j in stop:
            st+=1
    if s ==st:
        t_.append(i)    
t = t_

p = []
for i in pred:
    for j in i:
        if j:
            p.append(j)
            
p_ = []
for i in p:
    s,st =0, 0
    for j in i:
        if j in start:
            s+=1
        if j in stop:
            st+=1
    if s ==st:
        p_.append(i)    
p = p_


tp, fp, fn = len(set(p).intersection(t)) , len(set(p) - set(t)), len(set(t) - set(p))

pre = tp/(tp+fp)
rec = tp/(tp+fn)
f1 = 2*((pre*rec)/(pre+rec))

print(f"prec is {pre}\n  recall is {rec}\n f1 score is {f1}")

import json

with open('/home/hemant/asr_wm/data/res/''wswlm.json', "w") as f:
    json.dump(f"prec is {pre}\n  recall is {rec}\n f1 score is {f1}\n for {d_t}",f)
# Out:
# prec is 0.9862295081967213
#   recall is 0.7372549019607844
#  f1 score is 0.8437587657784011

# %%
path = "/home/hemant/asr_wm/data/save/without_space/with_lm/"
d_t = 'test'

import numpy as np
from tqdm import tqdm
import glob, os

start = [ "|", "$", "{"]
stop = [']']

def rea(file):
    with open(file, 'r') as f:
        dummy = f.read()
    l = ''
    w = ''
    for i in dummy:
        if i in start:
            l+= i
            w= '-'
        elif w == '-' and len(l) != 0:
            l+= i
        if i in stop:
            l+= ','
            w = ''
    return l[:-1].split(',')

true_ = glob.glob('/home/hemant/asr_wm/data/ner/txt/'+d_t+'/*.txt')
pred_ = glob.glob(path + d_t+ '/*.txt')

def step(true_,pred_):
    true = [rea(true_)]
    pred = [rea(pred_)]

    t = []
    for i in true:
        for j in i:
            t.append(j)

    t_ = []
    for i in t:
        s,st =0, 0
        for j in i:
            if j in start:
                s+=1
            if j in stop:
                st+=1
        if s ==st:
            t_.append(i)    
    t = t_

    p = []
    for i in pred:
        for j in i:
            if j:
                p.append(j)

    p_ = []
    for i in p:
        s,st =0, 0
        for j in i:
            if j in start:
                s+=1
            if j in stop:
                st+=1
        if s ==st:
            p_.append(i)    
    p = p_


    return len(set(p).intersection(t)) , len(set(p) - set(t)), len(set(t) - set(p))

tp,fp, fn = 0,0,0
for i in range(len(pred_)):
    assert os.path.basename(true_[i]) ==  os.path.basename(pred_[i])
    a,b,c = step(true_[i], pred_[i])
    tp+=a
    fp+=b
    fn+=c

pre = tp/(tp+fp)
rec = tp/(tp+fn)
f1 = 2*((pre*rec)/(pre+rec))

print(f"prec is {pre}\n  recall is {rec}\n f1 score is {f1}")
# Out:
# prec is 0.9700934579439252
#   recall is 0.7102292165583305
#  f1 score is 0.820067153861347
